# %% [markdown]
# # Assignment 2: MIP - International Industries, Inc.
#
# # By: Michael Church Carson (260683849)

# %% [markdown]
# ## import packages

# %%
import gurobipy as gp
from gurobipy import GRB
import numpy as np
import pandas as pd

# %% [markdown]
# # (a)

# %% [markdown]
# ## import problem data

# %%
indust = pd.read_excel('INT-INDUSTRIES-DATA.xls', sheet_name='Data', usecols = 'A,C:E', nrows = 150)
indust
# Out:
#      Division Number  Investment Required ($million)  \
# 0                  1                             600
# 1                  1                             400
# 2                  1                             150
# 3                  2                             300
# 4                  2                              40
# ..               ...                             ...
# 145               49                             200
# 146               49                             200
# 147               50                             350
# 148               50                             100
# 149               50                             300
#
#      Net Present Value ($million)  Cash Flow for Next Year ($million)
# 0                            -229                                -300
# 1                             -44                                 350
# 2                            -309                                -500
# ...

# %%
industries = np.asarray(indust)
industries
# Out:
# array([[   1,  600, -229, -300],
#        [   1,  400,  -44,  350],
#        [   1,  150, -309, -500],
#        [   2,  300, -257, -200],
#        [   2,   40,  -16,   35],
#        [   2,  400, 1100, 1600],
#        [   3,   35, 1089, 1200],
#        [   3,   25,  799,  900],
#        [   3,   25,  345,  400],
#        [   4,  200,  681,  900],
#        [   4,  400, -383, -700],
#        [   4,  200,  628,  800],
#        [   5,  100, -475, -600],
#        [   5,  200,  682,  900],
#        [   5,  300,  605, 1000],
#        [   6,  150, -248,   12],
#        [   6,  600,  319,   35],
#        [   6,  400,  858,   80],
#        [   7,  300, -371,   50],
#        [   7,  400,  649,  350],
#        [   7,   40,  160,  200],
#        [   8,   25, -104,   12],
#        [   8,   25,  264,   35],
#        [   8,   35, 1064,   80],
#        [   9,  400, -332,   50],
#        [   9,  200, 1240,  350],
#        [   9,  200,  532,  200],
#        [  10,  300,  344,   35],
# ...

# %% [markdown]
# ## Generate lists for variables Ii, Ni, and Ci

# %%
# Ii = investment required for decision to INVEST in each division d
# Ni = net present value for the decision to INVEST in each division d
# Ci = cash flow for next year for the decision to INVEST in division d

# %%
Ii = industries[[0,3,6,9,12,15,18,21,24,27,30,33,36,39,42,45,48,51,54,57,60,63,66,69,72,75,78,81,
                 84,87,90,93,96,99,102,105,108,111,114,117,120,123,126,129,132,135,138,141,144,147],1]

Ni = industries[[0,3,6,9,12,15,18,21,24,27,30,33,36,39,42,45,48,51,54,57,60,63,66,69,72,75,78,81,
                 84,87,90,93,96,99,102,105,108,111,114,117,120,123,126,129,132,135,138,141,144,147],2]

Ci = industries[[0,3,6,9,12,15,18,21,24,27,30,33,36,39,42,45,48,51,54,57,60,63,66,69,72,75,78,81,84,
                 87,90,93,96,99,102,105,108,111,114,117,120,123,126,129,132,135,138,141,144,147],3]

# %% [markdown]
# ## Generate lists for variables Im, Nm, and Cm

# %%
# Im = investment required for decision to MAINTAIN each division d
# Nm = net present value for the decision to MAINTAIN each division d
# Cm = cash flow for next year for the decision to MAINTAIN division d

# %%
Im = industries[[1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70,
                 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133,
                 136, 139, 142, 145, 148],1]

Nm = industries[[1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70,
                 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133,
                 136, 139, 142, 145, 148],2]

Cm = industries[[1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70,
                 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133,
                 136, 139, 142, 145, 148],3]

# %% [markdown]
# ## Generate lists for variables Is, Ns, and Cs

# %%
# Is = investment required for decision to SELL each division d
# Ns = net present value the decision to SELL each division d
# Cs = cash flow for next year for the decision to SELL division d

# %%
Is= industries[[2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74,
                77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137,
                140, 143, 146, 149],1]

Ns= industries[[2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74,
                77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137,
                140, 143, 146, 149],2]

Cs= industries[[2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74,
                77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137,
                140, 143, 146, 149],3]

# %%
n = len(Cs)
n
range(n)
# Out:
# range(0, 50)

# %% [markdown]
# ## Initiate the model

# %%
model = gp.Model("International Industries")

# %% [markdown]
# ## Define the decision variables and the objective function

# %%
I = model.addVars(n, vtype= GRB.BINARY, name = ["Invest_"+str(i) for i in range(n)])

# %%
M = model.addVars(n, vtype= GRB.BINARY, name = ["Maintain_"+str(i) for i in range(n)])

# %%
S = model.addVars(n, vtype= GRB.BINARY, name = ["Sell_"+str(i) for i in range(n)])

# %%
exp = sum(Ni[d]*I[d] + Nm[d]*M[d] + Ns[d]*S[d] for d in range(n))

# %%
model.setObjective(exp, GRB.MAXIMIZE)

# %% [markdown]
# ## Define the contraints

# %% [markdown]
# ## Total investment cannot exceed total cash flow for next year

# %%
model.addConstr(sum(Ii[d]*I[d] + Im[d]*M[d] + Is[d]*S[d] for d in range(n)) <= sum(Ci[d]*I[d] + Cm[d]*M[d] + Cs[d]*S[d] for d in range(n)))
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %% [markdown]
# ## Constraints based on portfolio restrictions (a) to (f) and the condition that Mr. Glasser must either invest, maitain, or sell each division.

# %%
model.addConstr(S[0]==I[0])

model.addConstr(S[0]==S[2])

model.addConstr(S[0]==S[3])

model.addConstr(I[5]==I[6])

model.addConstr(S[2] + S[3] + S[4] + M[5] + S[6] + S[8] <= 1)

model.addConstr(I[3] + M[5] + S[1] + S[5] + S[7] + S[11] + I[13] <= 1)

model.addConstr(I[23]<=I[27])

model.addConstr(M[29]<=M[31]+I[31])

model.addConstr(I[0] + M[0] + S[0] == 1)
model.addConstr(I[1] + M[1] + S[1] == 1)
model.addConstr(I[2] + M[2] + S[2] == 1)
model.addConstr(I[3] + M[3] + S[3] == 1)
model.addConstr(I[4] + M[4] + S[4] == 1)
model.addConstr(I[5] + M[5] + S[5] == 1)
model.addConstr(I[6] + M[6] + S[6] == 1)
model.addConstr(I[7] + M[7] + S[7] == 1)
model.addConstr(I[8] + M[8] + S[8] == 1)
model.addConstr(I[9] + M[9] + S[9] == 1)
model.addConstr(I[10] + M[10] + S[10] == 1)
model.addConstr(I[11] + M[11] + S[11] == 1)
model.addConstr(I[12] + M[12] + S[12] == 1)
model.addConstr(I[13] + M[13] + S[13] == 1)
model.addConstr(I[14] + M[14] + S[14] == 1)
model.addConstr(I[15] + M[15] + S[15] == 1)
model.addConstr(I[16] + M[16] + S[16] == 1)
model.addConstr(I[17] + M[17] + S[17] == 1)
model.addConstr(I[18] + M[18] + S[18] == 1)
model.addConstr(I[19] + M[19] + S[19] == 1)
model.addConstr(I[20] + M[20] + S[20] == 1)
model.addConstr(I[21] + M[21] + S[21] == 1)
model.addConstr(I[22] + M[22] + S[22] == 1)
model.addConstr(I[23] + M[23] + S[23] == 1)
model.addConstr(I[24] + M[24] + S[24] == 1)
model.addConstr(I[25] + M[25] + S[25] == 1)
model.addConstr(I[26] + M[26] + S[26] == 1)
model.addConstr(I[27] + M[27] + S[27] == 1)
model.addConstr(I[28] + M[28] + S[28] == 1)
model.addConstr(I[29] + M[29] + S[29] == 1)
model.addConstr(I[30] + M[30] + S[30] == 1)
model.addConstr(I[31] + M[31] + S[31] == 1)
model.addConstr(I[32] + M[32] + S[32] == 1)
model.addConstr(I[33] + M[33] + S[33] == 1)
model.addConstr(I[34] + M[34] + S[34] == 1)
model.addConstr(I[35] + M[35] + S[35] == 1)
model.addConstr(I[36] + M[36] + S[36] == 1)
model.addConstr(I[37] + M[37] + S[37] == 1)
model.addConstr(I[38] + M[38] + S[38] == 1)
model.addConstr(I[39] + M[39] + S[39] == 1)
model.addConstr(I[40] + M[40] + S[40] == 1)
model.addConstr(I[41] + M[41] + S[41] == 1)
model.addConstr(I[42] + M[42] + S[42] == 1)
model.addConstr(I[43] + M[43] + S[43] == 1)
model.addConstr(I[44] + M[44] + S[44] == 1)
model.addConstr(I[45] + M[45] + S[45] == 1)
model.addConstr(I[46] + M[46] + S[46] == 1)
model.addConstr(I[47] + M[47] + S[47] == 1)
model.addConstr(I[48] + M[48] + S[48] == 1)
model.addConstr(I[49] + M[49] + S[49] == 1)
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %% [markdown]
# ## Find the optimal solution

# %%
model.optimize()
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 59 rows, 150 columns and 321 nonzeros
# Model fingerprint: 0x65966b64
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 20565.000000
# Presolve removed 56 rows and 130 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 20 columns, 24 nonzeros
# Found heuristic solution: objective 32600.000000
# Variable types: 0 continuous, 20 integer (20 binary)
#
# Root relaxation: objective 3.419205e+04, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# ...

# %% [markdown]
# ## Show the optimal solution

# %%
model.objVal
# Out:
# 34036.0

# %% [markdown]
# ## Show the optimal values for the DVs

# %%
for var in model.getVars():
        print(var.varName, "=", var.x)
# Out:
# Invest_0 = 0.0
# Invest_1 = 0.0
# Invest_2 = 1.0
# Invest_3 = 0.0
# Invest_4 = 0.0
# Invest_5 = 1.0
# Invest_6 = 1.0
# Invest_7 = 0.0
# Invest_8 = 0.0
# Invest_9 = 0.0
# Invest_10 = 0.0
# Invest_11 = 0.0
# Invest_12 = 1.0
# Invest_13 = 0.0
# Invest_14 = 0.0
# Invest_15 = 0.0
# Invest_16 = 1.0
# Invest_17 = 1.0
# Invest_18 = 1.0
# Invest_19 = 0.0
# Invest_20 = 0.0
# Invest_21 = 1.0
# Invest_22 = 0.0
# Invest_23 = 0.0
# Invest_24 = 0.0
# Invest_25 = 1.0
# Invest_26 = 1.0
# Invest_27 = 0.0
# Invest_28 = 1.0
# Invest_29 = 1.0
# Invest_30 = 0.0
# Invest_31 = 0.0
# Invest_32 = 0.0
# Invest_33 = 0.0
# Invest_34 = 0.0
# Invest_35 = 0.0
# Invest_36 = 1.0
# Invest_37 = 1.0
# Invest_38 = 0.0
# Invest_39 = 1.0
# Invest_40 = 0.0
# Invest_41 = 1.0
# Invest_42 = 0.0
# Invest_43 = 1.0
# Invest_44 = 1.0
# Invest_45 = 0.0
# Invest_46 = 1.0
# Invest_47 = 0.0
# Invest_48 = 0.0
# Invest_49 = 1.0
# Maintain_0 = 1.0
# Maintain_1 = 0.0
# Maintain_2 = 0.0
# Maintain_3 = 1.0
# Maintain_4 = 1.0
# ...

# %% [markdown]
# ## (b)

# %% [markdown]
# ## Reformulate the problem without restrictions (a) to (f)

# %%
## import packages

import gurobipy as gp
from gurobipy import GRB
import numpy as np
import pandas as pd

## import problem data

indust = pd.read_excel('INT-INDUSTRIES-DATA.xls', sheet_name='Data', usecols = 'A,C:E', nrows = 150)
indust

industries = np.asarray(indust)
industries

Ii = industries[[0,3,6,9,12,15,18,21,24,27,30,33,36,39,42,45,48,51,54,57,60,63,66,69,72,75,78,81,
                 84,87,90,93,96,99,102,105,108,111,114,117,120,123,126,129,132,135,138,141,144,147],1]

Ni = industries[[0,3,6,9,12,15,18,21,24,27,30,33,36,39,42,45,48,51,54,57,60,63,66,69,72,75,78,81,
                 84,87,90,93,96,99,102,105,108,111,114,117,120,123,126,129,132,135,138,141,144,147],2]

Ci = industries[[0,3,6,9,12,15,18,21,24,27,30,33,36,39,42,45,48,51,54,57,60,63,66,69,72,75,78,81,84,
                 87,90,93,96,99,102,105,108,111,114,117,120,123,126,129,132,135,138,141,144,147],3]


Im = industries[[1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70,
                 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133,
                 136, 139, 142, 145, 148],1]

Nm = industries[[1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70,
                 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133,
                 136, 139, 142, 145, 148],2]

Cm = industries[[1, 4, 7, 10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49, 52, 55, 58, 61, 64, 67, 70,
                 73, 76, 79, 82, 85, 88, 91, 94, 97, 100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133,
                 136, 139, 142, 145, 148],3]

Is= industries[[2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74,
                77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137,
                140, 143, 146, 149],1]

Ns= industries[[2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74,
                77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137,
                140, 143, 146, 149],2]

Cs= industries[[2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74,
                77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113, 116, 119, 122, 125, 128, 131, 134, 137,
                140, 143, 146, 149],3]

n = len(Cs)
n
range(n)

## Initiate the model

model2 = gp.Model("International Industries")

## Define the decision variables and the objective function

I = model2.addVars(n, vtype= GRB.BINARY, name = ["Invest_"+str(i) for i in range(n)])

M = model2.addVars(n, vtype= GRB.BINARY, name = ["Maintain_"+str(i) for i in range(n)])

S = model2.addVars(n, vtype= GRB.BINARY, name = ["Sell_"+str(i) for i in range(n)])

exp = sum(Ni[d]*I[d] + Nm[d]*M[d] + Ns[d]*S[d] for d in range(n))

model2.setObjective(exp, GRB.MAXIMIZE)

## Define the contraints

## Total investment cannot exceed total cash flow for next year

model2.addConstr(sum(Ii[d]*I[d] + Im[d]*M[d] + Is[d]*S[d] for d in range(n)) <= sum(Ci[d]*I[d] + Cm[d]*M[d] + Cs[d]*S[d] for d in range(n)))

## ## Constraints for condition that Mr. Glasser must either invest, maitain, or sell each division. 

model2.addConstr(I[0] + M[0] + S[0] == 1)
model2.addConstr(I[1] + M[1] + S[1] == 1)
model2.addConstr(I[2] + M[2] + S[2] == 1)
model2.addConstr(I[3] + M[3] + S[3] == 1)
model2.addConstr(I[4] + M[4] + S[4] == 1)
model2.addConstr(I[5] + M[5] + S[5] == 1)
model2.addConstr(I[6] + M[6] + S[6] == 1)
model2.addConstr(I[7] + M[7] + S[7] == 1)
model2.addConstr(I[8] + M[8] + S[8] == 1)
model2.addConstr(I[9] + M[9] + S[9] == 1)
model2.addConstr(I[10] + M[10] + S[10] == 1)
model2.addConstr(I[11] + M[11] + S[11] == 1)
model2.addConstr(I[12] + M[12] + S[12] == 1)
model2.addConstr(I[13] + M[13] + S[13] == 1)
model2.addConstr(I[14] + M[14] + S[14] == 1)
model2.addConstr(I[15] + M[15] + S[15] == 1)
model2.addConstr(I[16] + M[16] + S[16] == 1)
model2.addConstr(I[17] + M[17] + S[17] == 1)
model2.addConstr(I[18] + M[18] + S[18] == 1)
model2.addConstr(I[19] + M[19] + S[19] == 1)
model2.addConstr(I[20] + M[20] + S[20] == 1)
model2.addConstr(I[21] + M[21] + S[21] == 1)
model2.addConstr(I[22] + M[22] + S[22] == 1)
model2.addConstr(I[23] + M[23] + S[23] == 1)
model2.addConstr(I[24] + M[24] + S[24] == 1)
model2.addConstr(I[25] + M[25] + S[25] == 1)
model2.addConstr(I[26] + M[26] + S[26] == 1)
model2.addConstr(I[27] + M[27] + S[27] == 1)
model2.addConstr(I[28] + M[28] + S[28] == 1)
model2.addConstr(I[29] + M[29] + S[29] == 1)
model2.addConstr(I[30] + M[30] + S[30] == 1)
model2.addConstr(I[31] + M[31] + S[31] == 1)
model2.addConstr(I[32] + M[32] + S[32] == 1)
model2.addConstr(I[33] + M[33] + S[33] == 1)
model2.addConstr(I[34] + M[34] + S[34] == 1)
model2.addConstr(I[35] + M[35] + S[35] == 1)
model2.addConstr(I[36] + M[36] + S[36] == 1)
model2.addConstr(I[37] + M[37] + S[37] == 1)
model2.addConstr(I[38] + M[38] + S[38] == 1)
model2.addConstr(I[39] + M[39] + S[39] == 1)
model2.addConstr(I[40] + M[40] + S[40] == 1)
model2.addConstr(I[41] + M[41] + S[41] == 1)
model2.addConstr(I[42] + M[42] + S[42] == 1)
model2.addConstr(I[43] + M[43] + S[43] == 1)
model2.addConstr(I[44] + M[44] + S[44] == 1)
model2.addConstr(I[45] + M[45] + S[45] == 1)
model2.addConstr(I[46] + M[46] + S[46] == 1)
model2.addConstr(I[47] + M[47] + S[47] == 1)
model2.addConstr(I[48] + M[48] + S[48] == 1)
model2.addConstr(I[49] + M[49] + S[49] == 1)
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %% [markdown]
# ## Find the optimal solution

# %%
model2.optimize()
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 51 rows, 150 columns and 295 nonzeros
# Model fingerprint: 0x60c7155f
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 23288.000000
# Presolve removed 51 rows and 150 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.04 seconds
# Thread count was 1 (of 4 available processors)
#
# Solution count 2: 39625 23288
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.962500000000e+04, best bound 3.962500000000e+04, gap 0.0000%

# %% [markdown]
# ## Show the optimal solution

# %%
model2.objVal
# Out:
# 39625.0

# %% [markdown]
# ## Show the optimal values for the DVs

# %%
for var in model2.getVars():
        print(var.varName, "=", var.x)
# Out:
# Invest_0 = 0.0
# Invest_1 = 0.0
# Invest_2 = 1.0
# Invest_3 = 1.0
# Invest_4 = 0.0
# Invest_5 = 0.0
# Invest_6 = 0.0
# Invest_7 = 0.0
# Invest_8 = 0.0
# Invest_9 = 0.0
# Invest_10 = 0.0
# Invest_11 = 0.0
# Invest_12 = 1.0
# Invest_13 = 1.0
# Invest_14 = 0.0
# Invest_15 = 0.0
# Invest_16 = 1.0
# Invest_17 = 1.0
# Invest_18 = 1.0
# Invest_19 = 0.0
# Invest_20 = 0.0
# Invest_21 = 1.0
# Invest_22 = 0.0
# Invest_23 = 1.0
# Invest_24 = 0.0
# Invest_25 = 1.0
# Invest_26 = 1.0
# Invest_27 = 0.0
# Invest_28 = 1.0
# Invest_29 = 1.0
# Invest_30 = 0.0
# Invest_31 = 0.0
# Invest_32 = 0.0
# Invest_33 = 0.0
# Invest_34 = 0.0
# Invest_35 = 0.0
# Invest_36 = 1.0
# Invest_37 = 1.0
# Invest_38 = 0.0
# Invest_39 = 1.0
# Invest_40 = 0.0
# Invest_41 = 1.0
# Invest_42 = 0.0
# Invest_43 = 1.0
# Invest_44 = 1.0
# Invest_45 = 0.0
# Invest_46 = 1.0
# Invest_47 = 0.0
# Invest_48 = 0.0
# Invest_49 = 1.0
# Maintain_0 = 1.0
# Maintain_1 = 0.0
# Maintain_2 = 0.0
# Maintain_3 = 0.0
# Maintain_4 = 1.0
# ...

# %% [markdown]
# ## Calculate the penalty for imposing restrictions (a) to (f)

# %%
penalty = model2.objVal - model.objVal

print(penalty)
# Out:
# 5589.0

# %% [markdown]
# ## (c) - second best solution

# %% [markdown]
# ## Re-run model from part (a) with the new contstraint limiting the total NPV

# %%
## Initiate the model

model3 = gp.Model("International Industries")

## Define the decision variables and the objective function

I = model3.addVars(n, vtype= GRB.BINARY, name = ["Invest_"+str(i) for i in range(n)])

M = model3.addVars(n, vtype= GRB.BINARY, name = ["Maintain_"+str(i) for i in range(n)])

S = model3.addVars(n, vtype= GRB.BINARY, name = ["Sell_"+str(i) for i in range(n)])

exp = sum(Ni[d]*I[d] + Nm[d]*M[d] + Ns[d]*S[d] for d in range(n))

model3.setObjective(exp, GRB.MAXIMIZE)

## Define the contraints

## Total investment cannot exceed total cash flow for next year

model3.addConstr(sum(Ii[d]*I[d] + Im[d]*M[d] + Is[d]*S[d] for d in range(n)) <= sum(Ci[d]*I[d] + Cm[d]*M[d] + Cs[d]*S[d] for d in range(n)))

## New constraint limiting the total NPV

model3.addConstr(sum(Ni[d]*I[d] + Nm[d]*M[d] + Ns[d]*S[d] for d in range(n)) <= 34035)

## Constraints based on portfolio restrictions (a) to (f) and the condition that 
# Mr. Glasser must either invest, maitain, or sell each division. 

model3.addConstr(S[0]==I[0])

model3.addConstr(S[0]==S[2])

model3.addConstr(S[0]==S[3])

model3.addConstr(I[5]==I[6])

model3.addConstr(S[2] + S[3] + S[4] + M[5] + S[6] + S[8] <= 1)

model3.addConstr(I[3] + M[5] + S[1] + S[5] + S[7] + S[11] + I[13] <= 1)

model3.addConstr(I[23]<=I[27])

model3.addConstr(M[29]<=M[31]+I[31])

model3.addConstr(I[0] + M[0] + S[0] == 1)
model3.addConstr(I[1] + M[1] + S[1] == 1)
model3.addConstr(I[2] + M[2] + S[2] == 1)
model3.addConstr(I[3] + M[3] + S[3] == 1)
model3.addConstr(I[4] + M[4] + S[4] == 1)
model3.addConstr(I[5] + M[5] + S[5] == 1)
model3.addConstr(I[6] + M[6] + S[6] == 1)
model3.addConstr(I[7] + M[7] + S[7] == 1)
model3.addConstr(I[8] + M[8] + S[8] == 1)
model3.addConstr(I[9] + M[9] + S[9] == 1)
model3.addConstr(I[10] + M[10] + S[10] == 1)
model3.addConstr(I[11] + M[11] + S[11] == 1)
model3.addConstr(I[12] + M[12] + S[12] == 1)
model3.addConstr(I[13] + M[13] + S[13] == 1)
model3.addConstr(I[14] + M[14] + S[14] == 1)
model3.addConstr(I[15] + M[15] + S[15] == 1)
model3.addConstr(I[16] + M[16] + S[16] == 1)
model3.addConstr(I[17] + M[17] + S[17] == 1)
model3.addConstr(I[18] + M[18] + S[18] == 1)
model3.addConstr(I[19] + M[19] + S[19] == 1)
model3.addConstr(I[20] + M[20] + S[20] == 1)
model3.addConstr(I[21] + M[21] + S[21] == 1)
model3.addConstr(I[22] + M[22] + S[22] == 1)
model3.addConstr(I[23] + M[23] + S[23] == 1)
model3.addConstr(I[24] + M[24] + S[24] == 1)
model3.addConstr(I[25] + M[25] + S[25] == 1)
model3.addConstr(I[26] + M[26] + S[26] == 1)
model3.addConstr(I[27] + M[27] + S[27] == 1)
model3.addConstr(I[28] + M[28] + S[28] == 1)
model3.addConstr(I[29] + M[29] + S[29] == 1)
model3.addConstr(I[30] + M[30] + S[30] == 1)
model3.addConstr(I[31] + M[31] + S[31] == 1)
model3.addConstr(I[32] + M[32] + S[32] == 1)
model3.addConstr(I[33] + M[33] + S[33] == 1)
model3.addConstr(I[34] + M[34] + S[34] == 1)
model3.addConstr(I[35] + M[35] + S[35] == 1)
model3.addConstr(I[36] + M[36] + S[36] == 1)
model3.addConstr(I[37] + M[37] + S[37] == 1)
model3.addConstr(I[38] + M[38] + S[38] == 1)
model3.addConstr(I[39] + M[39] + S[39] == 1)
model3.addConstr(I[40] + M[40] + S[40] == 1)
model3.addConstr(I[41] + M[41] + S[41] == 1)
model3.addConstr(I[42] + M[42] + S[42] == 1)
model3.addConstr(I[43] + M[43] + S[43] == 1)
model3.addConstr(I[44] + M[44] + S[44] == 1)
model3.addConstr(I[45] + M[45] + S[45] == 1)
model3.addConstr(I[46] + M[46] + S[46] == 1)
model3.addConstr(I[47] + M[47] + S[47] == 1)
model3.addConstr(I[48] + M[48] + S[48] == 1)
model3.addConstr(I[49] + M[49] + S[49] == 1)
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
## Find the optimal solution

model3.optimize()
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 60 rows, 150 columns and 471 nonzeros
# Model fingerprint: 0xd8555183
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+04]
# Found heuristic solution: objective 19851.000000
# Presolve removed 8 rows and 26 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 124 columns, 327 nonzeros
# Variable types: 0 continuous, 124 integer (124 binary)
#
# Root relaxation: objective 3.403500e+04, 35 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 34035.0000    0    6 19851.0000 34035.0000  71.5%     -    0s
# ...

# %% [markdown]
# ## Show the optimal solution

# %%
model3.objVal
# Out:
# 34006.0

# %% [markdown]
# ## Show the optimal values for the DVs

# %%
for var in model3.getVars():
        print(var.varName, "=", var.x)
# Out:
# Invest_0 = 0.0
# Invest_1 = -0.0
# Invest_2 = 1.0
# Invest_3 = 0.0
# Invest_4 = 0.0
# Invest_5 = 1.0
# Invest_6 = 1.0
# Invest_7 = -0.0
# Invest_8 = -0.0
# Invest_9 = 0.0
# Invest_10 = -0.0
# Invest_11 = 0.0
# Invest_12 = 1.0
# Invest_13 = -0.0
# Invest_14 = -0.0
# Invest_15 = -0.0
# Invest_16 = 1.0
# Invest_17 = 1.0
# Invest_18 = 1.0
# Invest_19 = -0.0
# Invest_20 = -0.0
# Invest_21 = 1.0
# Invest_22 = -0.0
# Invest_23 = 0.0
# Invest_24 = 0.0
# Invest_25 = 1.0
# Invest_26 = 1.0
# Invest_27 = 0.0
# Invest_28 = 1.0
# Invest_29 = 1.0
# Invest_30 = -0.0
# Invest_31 = -0.0
# Invest_32 = 0.0
# Invest_33 = 0.0
# Invest_34 = -0.0
# Invest_35 = -0.0
# Invest_36 = 0.0
# Invest_37 = 1.0
# Invest_38 = -0.0
# Invest_39 = 1.0
# Invest_40 = -0.0
# Invest_41 = 1.0
# Invest_42 = -0.0
# Invest_43 = 1.0
# Invest_44 = 1.0
# Invest_45 = -0.0
# Invest_46 = 1.0
# Invest_47 = -0.0
# Invest_48 = -0.0
# Invest_49 = 1.0
# Maintain_0 = 1.0
# Maintain_1 = 0.0
# Maintain_2 = -0.0
# Maintain_3 = 1.0
# ...

# %% [markdown]
# ## (c) - third best solution

# %%
## Initiate the model

model4 = gp.Model("International Industries")

## Define the decision variables and the objective function

I = model4.addVars(n, vtype= GRB.BINARY, name = ["Invest_"+str(i) for i in range(n)])

M = model4.addVars(n, vtype= GRB.BINARY, name = ["Maintain_"+str(i) for i in range(n)])

S = model4.addVars(n, vtype= GRB.BINARY, name = ["Sell_"+str(i) for i in range(n)])

exp = sum(Ni[d]*I[d] + Nm[d]*M[d] + Ns[d]*S[d] for d in range(n))

model4.setObjective(exp, GRB.MAXIMIZE)

## Define the contraints

## Total investment cannot exceed total cash flow for next year

model4.addConstr(sum(Ii[d]*I[d] + Im[d]*M[d] + Is[d]*S[d] for d in range(n)) <= sum(Ci[d]*I[d] + Cm[d]*M[d] + Cs[d]*S[d] for d in range(n)))

## New constraint limiting the total NPV

model4.addConstr(sum(Ni[d]*I[d] + Nm[d]*M[d] + Ns[d]*S[d] for d in range(n)) <= 34005)

## Constraints based on portfolio restrictions (a) to (f) and the condition that 
# Mr. Glasser must either invest, maitain, or sell each division. 

model4.addConstr(S[0]==I[0])

model4.addConstr(S[0]==S[2])

model4.addConstr(S[0]==S[3])

model4.addConstr(I[5]==I[6])

model4.addConstr(S[2] + S[3] + S[4] + M[5] + S[6] + S[8] <= 1)

model4.addConstr(I[3] + M[5] + S[1] + S[5] + S[7] + S[11] + I[13] <= 1)

model4.addConstr(I[23]<=I[27])

model4.addConstr(M[29]<=M[31]+I[31])

model4.addConstr(I[0] + M[0] + S[0] == 1)
model4.addConstr(I[1] + M[1] + S[1] == 1)
model4.addConstr(I[2] + M[2] + S[2] == 1)
model4.addConstr(I[3] + M[3] + S[3] == 1)
model4.addConstr(I[4] + M[4] + S[4] == 1)
model4.addConstr(I[5] + M[5] + S[5] == 1)
model4.addConstr(I[6] + M[6] + S[6] == 1)
model4.addConstr(I[7] + M[7] + S[7] == 1)
model4.addConstr(I[8] + M[8] + S[8] == 1)
model4.addConstr(I[9] + M[9] + S[9] == 1)
model4.addConstr(I[10] + M[10] + S[10] == 1)
model4.addConstr(I[11] + M[11] + S[11] == 1)
model4.addConstr(I[12] + M[12] + S[12] == 1)
model4.addConstr(I[13] + M[13] + S[13] == 1)
model4.addConstr(I[14] + M[14] + S[14] == 1)
model4.addConstr(I[15] + M[15] + S[15] == 1)
model4.addConstr(I[16] + M[16] + S[16] == 1)
model4.addConstr(I[17] + M[17] + S[17] == 1)
model4.addConstr(I[18] + M[18] + S[18] == 1)
model4.addConstr(I[19] + M[19] + S[19] == 1)
model4.addConstr(I[20] + M[20] + S[20] == 1)
model4.addConstr(I[21] + M[21] + S[21] == 1)
model4.addConstr(I[22] + M[22] + S[22] == 1)
model4.addConstr(I[23] + M[23] + S[23] == 1)
model4.addConstr(I[24] + M[24] + S[24] == 1)
model4.addConstr(I[25] + M[25] + S[25] == 1)
model4.addConstr(I[26] + M[26] + S[26] == 1)
model4.addConstr(I[27] + M[27] + S[27] == 1)
model4.addConstr(I[28] + M[28] + S[28] == 1)
model4.addConstr(I[29] + M[29] + S[29] == 1)
model4.addConstr(I[30] + M[30] + S[30] == 1)
model4.addConstr(I[31] + M[31] + S[31] == 1)
model4.addConstr(I[32] + M[32] + S[32] == 1)
model4.addConstr(I[33] + M[33] + S[33] == 1)
model4.addConstr(I[34] + M[34] + S[34] == 1)
model4.addConstr(I[35] + M[35] + S[35] == 1)
model4.addConstr(I[36] + M[36] + S[36] == 1)
model4.addConstr(I[37] + M[37] + S[37] == 1)
model4.addConstr(I[38] + M[38] + S[38] == 1)
model4.addConstr(I[39] + M[39] + S[39] == 1)
model4.addConstr(I[40] + M[40] + S[40] == 1)
model4.addConstr(I[41] + M[41] + S[41] == 1)
model4.addConstr(I[42] + M[42] + S[42] == 1)
model4.addConstr(I[43] + M[43] + S[43] == 1)
model4.addConstr(I[44] + M[44] + S[44] == 1)
model4.addConstr(I[45] + M[45] + S[45] == 1)
model4.addConstr(I[46] + M[46] + S[46] == 1)
model4.addConstr(I[47] + M[47] + S[47] == 1)
model4.addConstr(I[48] + M[48] + S[48] == 1)
model4.addConstr(I[49] + M[49] + S[49] == 1)
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %% [markdown]
# ## Find the optimal solution

# %%
model4.optimize()
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 60 rows, 150 columns and 471 nonzeros
# Model fingerprint: 0x989260b7
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+04]
# Found heuristic solution: objective 19851.000000
# Presolve removed 8 rows and 26 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 124 columns, 327 nonzeros
# Variable types: 0 continuous, 124 integer (124 binary)
#
# Root relaxation: objective 3.400500e+04, 35 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 34005.0000    0    6 19851.0000 34005.0000  71.3%     -    0s
# ...

# %% [markdown]
# ## Show the optimal solution

# %%
model4.objVal
# Out:
# 33999.0

# %% [markdown]
# ## Show the optimal values for the DVs

# %%
for var in model4.getVars():
        print(var.varName, "=", var.x)
# Out:
# Invest_0 = 0.0
# Invest_1 = -0.0
# Invest_2 = 1.0
# Invest_3 = 0.0
# Invest_4 = 0.0
# Invest_5 = 1.0
# Invest_6 = 1.0
# Invest_7 = -0.0
# Invest_8 = -0.0
# Invest_9 = -0.0
# Invest_10 = -0.0
# Invest_11 = -0.0
# Invest_12 = 1.0
# Invest_13 = -0.0
# Invest_14 = -0.0
# Invest_15 = -0.0
# Invest_16 = 1.0
# Invest_17 = 1.0
# Invest_18 = 1.0
# Invest_19 = -0.0
# Invest_20 = -0.0
# Invest_21 = 1.0
# Invest_22 = -0.0
# Invest_23 = -0.0
# Invest_24 = -0.0
# Invest_25 = 1.0
# Invest_26 = 1.0
# Invest_27 = 0.0
# Invest_28 = 1.0
# Invest_29 = 1.0
# Invest_30 = -0.0
# Invest_31 = -0.0
# Invest_32 = 0.0
# Invest_33 = -0.0
# Invest_34 = -0.0
# Invest_35 = -0.0
# Invest_36 = -0.0
# Invest_37 = 1.0
# Invest_38 = -0.0
# Invest_39 = 1.0
# Invest_40 = -0.0
# Invest_41 = 1.0
# Invest_42 = -0.0
# Invest_43 = 1.0
# Invest_44 = 1.0
# Invest_45 = -0.0
# Invest_46 = 1.0
# Invest_47 = -0.0
# Invest_48 = -0.0
# Invest_49 = 1.0
# Maintain_0 = 1.0
# Maintain_1 = 0.0
# Maintain_2 = -0.0
# Maintain_3 = 1.0
# ...

# %% [markdown]
# ## END
#
# ## Michael Church Carson
